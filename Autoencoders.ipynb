# %%
import tensorflow as tf
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
#PATH = './content'
PATH = '/content/drive/MyDrive/DEEP LEAR/UAP/dataset'
IMAGE_SIZE = 32
data = []

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load data from mnist
# (X_train, y_train), (X_test, y_test) = cifar10.load_data()
# X_train = X_train.astype('float32') / 255.0
# X_test = X_test.astype('float32') / 255.0
# X_train = tf.random.shuffle(X_train, seed=19)
# X_test = tf.random.shuffle(X_test, seed=19)
# X_train

# %%
tf.random.set_seed(19)
np.random.seed(19)


for file_name in os.listdir(PATH):
    image = tf.keras.preprocessing.image.load_img(PATH + '/' + file_name,
                                                      target_size=(IMAGE_SIZE, IMAGE_SIZE))
    image = tf.keras.preprocessing.image.img_to_array(image)
    data.append(image)

data = tf.random.shuffle(data, seed=19)
data = np.array(data)
data = data.astype('float32') / 255.0

train_size = int(len(data) * 0.65)
train_data = data[:train_size]
test_data = data[train_size:]

# %%
hidden_dim = 512
latent_dim = 32
epochs = 1000
batch_size = 100
learning_rate = 0.00015

# %%
class CVAE(tf.keras.Model):
    def __init__(self, dim, **kwargs):
        h_dim = dim[0]
        z_dim = dim[1]
        super(CVAE, self).__init__(**kwargs)
        self._name = "Convolutional Variational Autoencoder"

        # Encoder
        self.conv = tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', strides=(2, 2), padding='same')
        self.conv._name = "encoder_Conv2D"
        self.pool = tf.keras.layers.MaxPool2D((2, 2), padding='same')
        self.pool._name = "encoder_MaxPool2D"
        self.flatten = tf.keras.layers.Flatten()
        self.flatten._name = "encoder_flatten"
        self.fc1 = tf.keras.layers.Dense(h_dim)
        self.fc1._name = "encoder_fc"
        self.fc2_mu = tf.keras.layers.Dense(z_dim)
        self.fc2_mu._name = "encoder_fc_mu"
        self.fc2_log_var = tf.keras.layers.Dense(z_dim)
        self.fc2_log_var._name = "encoder_fc_log_var"

        # Decoder
        self.fc3 = tf.keras.layers.Dense(h_dim, activation='relu')
        self.fc3._name = "decoder_fc"
        self.fc4 = tf.keras.layers.Dense(16 * 16 * 32, activation='relu')
        self.fc4._name = "decoder_fc"
        self.reshape = tf.keras.layers.Reshape((16, 16, 32))
        self.reshape._name = "decoder_reshape"
        self.deconv = tf.keras.layers.Conv2DTranspose(3, kernel_size=(3, 3), strides=(2,2), padding='same')
        self.deconv._name = "decoder_Conv2DTranspose"

    def encode(self, x):
        x = self.conv(x)
        x = self.pool(x)
        x = self.flatten(x)
        h = tf.nn.relu(self.fc1(x))
        return self.fc2_mu(h), self.fc2_log_var(h)

    def reparameterize(self, mu, log_var):
        std = tf.exp(log_var * 0.5)
        eps = tf.random.normal(std.shape)
        return mu + eps * std

    def decode_logits(self, z):
        z = self.fc3(z)
        z = self.fc4(z)
        z = self.reshape(z)
        return self.deconv(z)

    def decode(self, z):
        return tf.nn.sigmoid(self.decode_logits(z))

    def call(self, inputs, training=None, mask=None):
        mu, log_var = self.encode(inputs)
        z = self.reparameterize(mu, log_var)
        x_reconstructed_logits = self.decode_logits(z)
        return x_reconstructed_logits, mu, log_var


model = CVAE([hidden_dim, latent_dim])
X_train = train_data.reshape((-1, IMAGE_SIZE, IMAGE_SIZE, 3))
X_test = test_data.reshape((-1, IMAGE_SIZE, IMAGE_SIZE, 3))

# %%
model.build(input_shape=(batch_size, IMAGE_SIZE, IMAGE_SIZE, 3))
print(model.summary())

optimizer = tf.keras.optimizers.Adam(learning_rate)

dataset = tf.data.Dataset.from_tensor_slices(X_train)
dataset = dataset.shuffle(batch_size * 5).batch(batch_size)
num_batches = X_train.shape[0] // batch_size

loss_list = []
kldiv_list = []
# Out:
# Model: "Convolutional Variational Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_Conv2D (Conv2D)     multiple                  896
#
#  encoder_MaxPool2D (MaxPool  multiple                  0
#  ing2D)
#
#  encoder_flatten (Flatten)   multiple                  0
#
#  encoder_fc (Dense)          multiple                  1049088
#
#  encoder_fc_mu (Dense)       multiple                  16416
#
#  encoder_fc_log_var (Dense)  multiple                  16416
#
#  decoder_fc (Dense)          multiple                  16896
#
#  decoder_fc (Dense)          multiple                  4202496
#
#  decoder_reshape (Reshape)   multiple                  0
#
#  decoder_Conv2DTranspose (C  multiple                  867
#  onv2DTranspose)
#
# =================================================================
# Total params: 5303075 (20.23 MB)
# Trainable params: 5303075 (20.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
for epoch in range(epochs):
    for step, x in enumerate(dataset):
        x = tf.reshape(x, [-1, IMAGE_SIZE, IMAGE_SIZE, 3])
        with tf.GradientTape() as tape:
            x_reconstruction_logits, mu, log_var = model(x)

            reconstruction_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=x, logits=x_reconstruction_logits)
            reconstruction_loss = tf.reduce_sum(reconstruction_loss) / batch_size
            kl_div = - 0.5 * tf.reduce_sum(1. + log_var - tf.square(mu) - tf.exp(log_var), axis=-1)
            kl_div = tf.reduce_mean(kl_div)

            loss = tf.reduce_mean(reconstruction_loss) + kl_div

        gradients = tape.gradient(loss, model.trainable_variables)
        for g in gradients:
            tf.clip_by_norm(g, 15)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))

        if (step + 1) % 5 == 0:
            loss_list.append(reconstruction_loss)
            kldiv_list.append(kl_div)
            print(
                f"Epoch[{epoch + 1}/{epochs}], Step[{step + 1}/{num_batches}], Reconstruction Loss: {float(reconstruction_loss):.2f}, KL Div: {float(kl_div):.2f}")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x785b71f14280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x785b71f14280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch[1/1000], Step[5/5], Reconstruction Loss: 2126.14, KL Div: 0.27
# Epoch[2/1000], Step[5/5], Reconstruction Loss: 2121.55, KL Div: 0.32
# Epoch[3/1000], Step[5/5], Reconstruction Loss: 2116.64, KL Div: 0.39
# Epoch[4/1000], Step[5/5], Reconstruction Loss: 2109.47, KL Div: 0.77
# Epoch[5/1000], Step[5/5], Reconstruction Loss: 2104.98, KL Div: 1.56
# Epoch[6/1000], Step[5/5], Reconstruction Loss: 2099.09, KL Div: 1.76
# Epoch[7/1000], Step[5/5], Reconstruction Loss: 2093.60, KL Div: 1.97
# Epoch[8/1000], Step[5/5], Reconstruction Loss: 2081.23, KL Div: 2.35
# Epoch[9/1000], Step[5/5], Reconstruction Loss: 2082.85, KL Div: 2.61
# Epoch[10/1000], Step[5/5], Reconstruction Loss: 2064.45, KL Div: 2.70
# Epoch[11/1000], Step[5/5], Reconstruction Loss: 2057.49, KL Div: 3.32
# Epoch[12/1000], Step[5/5], Reconstruction Loss: 2057.13, KL Div: 4.27
# Epoch[13/1000], Step[5/5], Reconstruction Loss: 2052.92, KL Div: 4.54
# Epoch[14/1000], Step[5/5], Reconstruction Loss: 2038.05, KL Div: 5.72
# Epoch[15/1000], Step[5/5], Reconstruction Loss: 2007.54, KL Div: 8.35
# Epoch[16/1000], Step[5/5], Reconstruction Loss: 2020.94, KL Div: 8.13
# Epoch[17/1000], Step[5/5], Reconstruction Loss: 2014.74, KL Div: 9.04
# Epoch[18/1000], Step[5/5], Reconstruction Loss: 1983.41, KL Div: 11.18
# Epoch[19/1000], Step[5/5], Reconstruction Loss: 1994.57, KL Div: 10.94
# Epoch[20/1000], Step[5/5], Reconstruction Loss: 1970.72, KL Div: 12.68
# Epoch[21/1000], Step[5/5], Reconstruction Loss: 1919.66, KL Div: 15.33
# Epoch[22/1000], Step[5/5], Reconstruction Loss: 1956.24, KL Div: 13.60
# Epoch[23/1000], Step[5/5], Reconstruction Loss: 1889.35, KL Div: 16.78
# Epoch[24/1000], Step[5/5], Reconstruction Loss: 1938.73, KL Div: 12.97
# Epoch[25/1000], Step[5/5], Reconstruction Loss: 1913.10, KL Div: 15.12
# Epoch[26/1000], Step[5/5], Reconstruction Loss: 1880.59, KL Div: 16.16
# Epoch[27/1000], Step[5/5], Reconstruction Loss: 1871.21, KL Div: 16.72
# Epoch[28/1000], Step[5/5], Reconstruction Loss: 1888.47, KL Div: 15.82
# Epoch[29/1000], Step[5/5], Reconstruction Loss: 1867.22, KL Div: 16.82
# Epoch[30/1000], Step[5/5], Reconstruction Loss: 1888.66, KL Div: 14.87
# Epoch[31/1000], Step[5/5], Reconstruction Loss: 1900.23, KL Div: 15.18
# Epoch[32/1000], Step[5/5], Reconstruction Loss: 1897.46, KL Div: 15.26
# Epoch[33/1000], Step[5/5], Reconstruction Loss: 1866.84, KL Div: 16.78
# Epoch[34/1000], Step[5/5], Reconstruction Loss: 1891.48, KL Div: 16.33
# Epoch[35/1000], Step[5/5], Reconstruction Loss: 1895.39, KL Div: 14.67
# Epoch[36/1000], Step[5/5], Reconstruction Loss: 1868.76, KL Div: 16.86
# Epoch[37/1000], Step[5/5], Reconstruction Loss: 1861.25, KL Div: 15.55
# Epoch[38/1000], Step[5/5], Reconstruction Loss: 1870.54, KL Div: 15.41
# Epoch[39/1000], Step[5/5], Reconstruction Loss: 1841.59, KL Div: 17.11
# Epoch[40/1000], Step[5/5], Reconstruction Loss: 1868.81, KL Div: 15.55
# Epoch[41/1000], Step[5/5], Reconstruction Loss: 1851.18, KL Div: 15.75
# Epoch[42/1000], Step[5/5], Reconstruction Loss: 1892.42, KL Div: 14.15
# Epoch[43/1000], Step[5/5], Reconstruction Loss: 1847.26, KL Div: 15.67
# Epoch[44/1000], Step[5/5], Reconstruction Loss: 1835.30, KL Div: 16.70
# Epoch[45/1000], Step[5/5], Reconstruction Loss: 1870.39, KL Div: 15.51
# Epoch[46/1000], Step[5/5], Reconstruction Loss: 1861.96, KL Div: 16.68
# Epoch[47/1000], Step[5/5], Reconstruction Loss: 1866.30, KL Div: 16.65
# Epoch[48/1000], Step[5/5], Reconstruction Loss: 1811.00, KL Div: 18.28
# Epoch[49/1000], Step[5/5], Reconstruction Loss: 1835.12, KL Div: 16.33
# Epoch[50/1000], Step[5/5], Reconstruction Loss: 1847.11, KL Div: 17.09
# Epoch[51/1000], Step[5/5], Reconstruction Loss: 1864.27, KL Div: 15.48
# Epoch[52/1000], Step[5/5], Reconstruction Loss: 1881.98, KL Div: 15.41
# Epoch[53/1000], Step[5/5], Reconstruction Loss: 1843.49, KL Div: 16.39
# Epoch[54/1000], Step[5/5], Reconstruction Loss: 1871.67, KL Div: 14.92
# Epoch[55/1000], Step[5/5], Reconstruction Loss: 1816.34, KL Div: 17.24
# Epoch[56/1000], Step[5/5], Reconstruction Loss: 1858.69, KL Div: 16.53
# Epoch[57/1000], Step[5/5], Reconstruction Loss: 1859.18, KL Div: 16.77
# Epoch[58/1000], Step[5/5], Reconstruction Loss: 1832.31, KL Div: 17.55
# Epoch[59/1000], Step[5/5], Reconstruction Loss: 1863.11, KL Div: 16.03
# Epoch[60/1000], Step[5/5], Reconstruction Loss: 1866.49, KL Div: 15.96
# Epoch[61/1000], Step[5/5], Reconstruction Loss: 1819.88, KL Div: 17.21
# Epoch[62/1000], Step[5/5], Reconstruction Loss: 1849.67, KL Div: 18.01
# Epoch[63/1000], Step[5/5], Reconstruction Loss: 1833.84, KL Div: 17.15
# Epoch[64/1000], Step[5/5], Reconstruction Loss: 1821.45, KL Div: 17.64
# Epoch[65/1000], Step[5/5], Reconstruction Loss: 1847.65, KL Div: 17.48
# Epoch[66/1000], Step[5/5], Reconstruction Loss: 1820.57, KL Div: 18.05
# Epoch[67/1000], Step[5/5], Reconstruction Loss: 1828.74, KL Div: 18.45
# Epoch[68/1000], Step[5/5], Reconstruction Loss: 1856.07, KL Div: 17.01
# Epoch[69/1000], Step[5/5], Reconstruction Loss: 1791.50, KL Div: 19.76
# Epoch[70/1000], Step[5/5], Reconstruction Loss: 1787.61, KL Div: 20.52
# Epoch[71/1000], Step[5/5], Reconstruction Loss: 1818.21, KL Div: 20.26
# Epoch[72/1000], Step[5/5], Reconstruction Loss: 1790.42, KL Div: 21.29
# Epoch[73/1000], Step[5/5], Reconstruction Loss: 1821.18, KL Div: 20.09
# Epoch[74/1000], Step[5/5], Reconstruction Loss: 1794.74, KL Div: 20.08
# Epoch[75/1000], Step[5/5], Reconstruction Loss: 1790.43, KL Div: 21.27
# Epoch[76/1000], Step[5/5], Reconstruction Loss: 1771.39, KL Div: 22.09
# Epoch[77/1000], Step[5/5], Reconstruction Loss: 1802.44, KL Div: 21.53
# Epoch[78/1000], Step[5/5], Reconstruction Loss: 1802.96, KL Div: 21.71
# Epoch[79/1000], Step[5/5], Reconstruction Loss: 1785.12, KL Div: 21.01
# Epoch[80/1000], Step[5/5], Reconstruction Loss: 1795.95, KL Div: 21.55
# Epoch[81/1000], Step[5/5], Reconstruction Loss: 1826.34, KL Div: 20.54
# Epoch[82/1000], Step[5/5], Reconstruction Loss: 1801.29, KL Div: 21.48
# Epoch[83/1000], Step[5/5], Reconstruction Loss: 1753.68, KL Div: 23.63
# Epoch[84/1000], Step[5/5], Reconstruction Loss: 1805.33, KL Div: 20.84
# Epoch[85/1000], Step[5/5], Reconstruction Loss: 1788.87, KL Div: 22.97
# Epoch[86/1000], Step[5/5], Reconstruction Loss: 1779.11, KL Div: 22.84
# Epoch[87/1000], Step[5/5], Reconstruction Loss: 1780.18, KL Div: 22.95
# Epoch[88/1000], Step[5/5], Reconstruction Loss: 1816.17, KL Div: 22.11
# Epoch[89/1000], Step[5/5], Reconstruction Loss: 1811.39, KL Div: 22.47
# Epoch[90/1000], Step[5/5], Reconstruction Loss: 1819.22, KL Div: 22.29
# Epoch[91/1000], Step[5/5], Reconstruction Loss: 1775.83, KL Div: 23.06
# Epoch[92/1000], Step[5/5], Reconstruction Loss: 1797.48, KL Div: 22.55
# Epoch[93/1000], Step[5/5], Reconstruction Loss: 1799.54, KL Div: 22.82
# Epoch[94/1000], Step[5/5], Reconstruction Loss: 1790.45, KL Div: 22.96
# Epoch[95/1000], Step[5/5], Reconstruction Loss: 1773.86, KL Div: 22.38
# Epoch[96/1000], Step[5/5], Reconstruction Loss: 1762.45, KL Div: 22.85
# Epoch[97/1000], Step[5/5], Reconstruction Loss: 1821.30, KL Div: 22.46
# Epoch[98/1000], Step[5/5], Reconstruction Loss: 1815.14, KL Div: 22.19
# Epoch[99/1000], Step[5/5], Reconstruction Loss: 1816.85, KL Div: 21.80
# Epoch[100/1000], Step[5/5], Reconstruction Loss: 1789.19, KL Div: 22.70
# Epoch[101/1000], Step[5/5], Reconstruction Loss: 1780.24, KL Div: 22.46
# Epoch[102/1000], Step[5/5], Reconstruction Loss: 1764.26, KL Div: 24.12
# Epoch[103/1000], Step[5/5], Reconstruction Loss: 1696.34, KL Div: 26.55
# Epoch[104/1000], Step[5/5], Reconstruction Loss: 1821.09, KL Div: 22.66
# Epoch[105/1000], Step[5/5], Reconstruction Loss: 1805.16, KL Div: 23.67
# Epoch[106/1000], Step[5/5], Reconstruction Loss: 1783.56, KL Div: 23.32
# Epoch[107/1000], Step[5/5], Reconstruction Loss: 1742.48, KL Div: 24.94
# Epoch[108/1000], Step[5/5], Reconstruction Loss: 1737.35, KL Div: 24.49
# Epoch[109/1000], Step[5/5], Reconstruction Loss: 1781.67, KL Div: 23.95
# Epoch[110/1000], Step[5/5], Reconstruction Loss: 1782.59, KL Div: 22.83
# Epoch[111/1000], Step[5/5], Reconstruction Loss: 1761.58, KL Div: 23.34
# Epoch[112/1000], Step[5/5], Reconstruction Loss: 1778.44, KL Div: 23.26
# Epoch[113/1000], Step[5/5], Reconstruction Loss: 1758.68, KL Div: 24.66
# Epoch[114/1000], Step[5/5], Reconstruction Loss: 1796.41, KL Div: 24.56
# Epoch[115/1000], Step[5/5], Reconstruction Loss: 1795.25, KL Div: 23.55
# Epoch[116/1000], Step[5/5], Reconstruction Loss: 1753.23, KL Div: 24.75
# Epoch[117/1000], Step[5/5], Reconstruction Loss: 1777.62, KL Div: 23.78
# Epoch[118/1000], Step[5/5], Reconstruction Loss: 1802.73, KL Div: 23.52
# Epoch[119/1000], Step[5/5], Reconstruction Loss: 1777.49, KL Div: 23.80
# Epoch[120/1000], Step[5/5], Reconstruction Loss: 1784.20, KL Div: 24.33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9bf12573306a> in <cell line: 1>()
#      15         for g in gradients:
#      16             tf.clip_by_norm(g, 15)
# ---> 17         optimizer.apply_gradients(zip(gradients, model.trainable_variables))
#      18
#      19         if (step + 1) % 5 == 0:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1221         if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1222             grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1223         return super().apply_gradients(grads_and_vars, name=name)
#    1224
#    1225     def _apply_weight_decay(self, variables):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in apply_gradients(self, grads_and_vars, name)
#     650             self._apply_weight_decay(trainable_variables)
#     651             grads_and_vars = list(zip(grads, trainable_variables))
# --> 652             iteration = self._internal_apply_gradients(grads_and_vars)
#     653
#     654             # Apply variable constraints after applying gradients.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in _internal_apply_gradients(self, grads_and_vars)
#    1251             return super()._internal_apply_gradients(grads_and_vars)
#    1252
# -> 1253         return tf.__internal__.distribute.interim.maybe_merge_call(
#    1254             self._distributed_apply_gradients_fn,
#    1255             self._distribution_strategy,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/merge_call_interim.py in maybe_merge_call(fn, strategy, *args, **kwargs)
#      49   """
#      50   if strategy_supports_no_merge_call():
# ---> 51     return fn(strategy, *args, **kwargs)
#      52   else:
#      53     return distribute_lib.get_replica_context().merge_call(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in _distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1343
#    1344         for grad, var in grads_and_vars:
# -> 1345             distribution.extended.update(
#    1346                 var, apply_grad_to_update_var, args=(grad,), group=False
#    1347             )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in update(self, var, fn, args, kwargs, group)
#    3011           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3012       with self._container_strategy().scope():
# -> 3013         return self._update(var, fn, args, kwargs, group)
#    3014     else:
#    3015       return self._replica_ctx_update(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _update(self, var, fn, args, kwargs, group)
#    4081     # The implementations of _update() and _update_non_slot() are identical
#    4082     # except _update() passes `var` as the first argument to `fn()`.
# -> 4083     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#    4084
#    4085   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4087     # once that value is used for something.
#    4088     with UpdateContext(colocate_with):
# -> 4089       result = fn(*args, **kwargs)
#    4090       if should_group:
#    4091         return result
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     594   def wrapper(*args, **kwargs):
#     595     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596       return func(*args, **kwargs)
#     597
#     598   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in apply_grad_to_update_var(var, grad)
#    1338         def apply_grad_to_update_var(var, grad):
#    1339             if self.jit_compile:
# -> 1340                 return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1341             else:
#    1342                 return self._update_step(grad, var)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     875       # In this case we have not created variables on the first call. So we can
#     876       # run the first trace but we should fail if variables are created.
# --> 877       results = tracing_compilation.call_function(
#     878           args, kwds, self._variable_creation_config
#     879       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     130   args = args if args else ()
#     131   kwargs = kwargs if kwargs else {}
# --> 132   function = trace_function(
#     133       args=args, kwargs=kwargs, tracing_options=tracing_options
#     134   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     228   )
#     229   lookup_func_type, lookup_func_context = (
# --> 230       function_type_utils.make_canonicalized_monomorphic_type(
#     231           args,
#     232           kwargs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/function_type_utils.py in make_canonicalized_monomorphic_type(args, kwargs, capture_types, polymorphic_type)
#     373
#     374   function_type, type_context = (
# --> 375       function_type_lib.canonicalize_to_monomorphic(
#     376           args, kwargs, {}, capture_types, polymorphic_type
#     377       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in canonicalize_to_monomorphic(args, kwargs, default_values, capture_types, polymorphic_type)
#     585                                      poly_parameter.type_constraint))
#     586
# --> 587   return FunctionType(parameters, capture_types), type_context
#     588
#     589
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in __init__(self, parameters, captures, **kwargs)
#     191                **kwargs):
#     192     super().__init__(parameters, **kwargs)
# --> 193     self._captures = captures if captures else collections.OrderedDict()
#     194
#     195   @property
#
# KeyboardInterrupt:

# %%
# plot loss and kl div
plt.figure(figsize=(20, 4))
plt.subplot(1, 2, 1)
plt.plot(loss_list, label='Reconstruction loss')
plt.title('Reconstruction Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(kldiv_list, label='KL Divergence')
plt.title('KL Divergence')
plt.ylabel('kl div')
plt.xlabel('Epoch')
plt.legend()
plt.savefig("Loss_KL_Div.png")
plt.show()

# %%
mu, log_var = model.encode(X_test)
print(np.array(mu).shape)
out = model.decode(mu)

print(type(model))
out = tf.reshape(out, [-1, IMAGE_SIZE, IMAGE_SIZE, 3]).numpy() * 255
out = out.astype(np.uint8)

number = 10

# Create a single figure with two rows and 'number' columns
# fig, axs = plt.subplots(2, number, figsize=(20, 4))

number = 10
plt.figure(figsize=(20, 4))
for i in range(number):
    ax = plt.subplot(2, number, i+1)
    plt.xlabel("Rec")
    plt.imshow(X_test[i+20], cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
for i in range(number):
    ax = plt.subplot(2, number, i + 11)
    plt.imshow(out[i+20], cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.savefig("Image_Autoencoders.png")
plt.show()
